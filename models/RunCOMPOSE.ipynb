# %% [markdown]
# Running Extreme Verification Latency Algorithms with the following classifiers:
# QN_S3VM
# Label Propagation
#
# The following parameters need to be passed in:
# 1. classifier : QN_S3VM or label_propagation
# 2. method : type of clustering 'gmm' or 'a_shape'
#     - gmm accounts for Fast COMPOSE
#     - a_shape accounts for alpha shapes
# 3. verbose : 0: doesnt print out , 1 prints to command line
# 4. num_cores: percent in which you wish to operate 0.8 = 80% of available cores
# 5. selected dataset : options available :
# ['UG_2C_2D','MG_2C_2D','1CDT', '2CDT', 'UG_2C_3D','1CHT','2CHT','4CR','4CREV1','4CREV2','5CVT','1CSURR', '4CE1CF','FG_2C_2D','GEARS_2C_2D', 'keystroke', 'UG_2C_5D', 'UnitTest']
#
# You are able to run in batch mode by running run_experiments.py
#
# You will need to instantiate RunExperiment Class and pass in the experiments, classifier, verbose, dataset, and number of cores.
#
# The number of cores is a percentage in which you want to operate: 1.0 means you will use all available cores, 0.8 means that you will use 80% of avaialable cores.

# %%
import run_experiments

experiment = run_experiments.RunExperiment(experiements=['fast_compose', 'compose'], classifier=['QN_S3VM', 'label_propagation'], 
                                            verbose=0, datasets=['UG_2C_2D','MG_2C_2D','1CDT', '2CDT'], num_cores=0.8)

run_it = experiment.run()
# Out:
# Run method:  0
# Available cores: 16
# Number of cores executing: 13
# Dataset: UG_2C_2D
# Method: gmm
# Drift window: [-4.0952, 13.077]
# SSL Classifier: QN_S3VM
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-882a3a8e4080> in <module>
#       4                                             verbose=0, datasets=['UG_2C_2D','MG_2C_2D','1CDT', '2CDT'], num_cores=0.8)
#       5
# ----> 6 run_it = experiment.run()
#
# ~/extreme_verification_latency/models/run_experiments.py in run(self)
#      56                     if i == 'fast_compose' and j == 'QN_S3VM':
#      57                         fast_compose_QNS3VM = compose.COMPOSE(classifier="QN_S3VM", method="gmm", verbose = 0, num_cores= self.num_cores, selected_dataset = dataset)
# ---> 58                         self.results['fast_compose_QN_S3VM']= fast_compose_QNS3VM.run()
#      59                     elif i == 'fast_compose' and j == 'label_propagation':
#      60                         fast_compose_label_prop = compose.COMPOSE(classifier="label_propagation", method="gmm", verbose = 0, num_cores= self.num_cores, selected_dataset = dataset)
#
# ~/extreme_verification_latency/models/compose.py in run(self)
#     425                         self.labeled[ts-1] = np.append(self.labeled[ts-1], np.ones((rows_to_add,np.shape(self.labeled[ts-1])[1])), axis=0)
#     426
# --> 427                     self.learner[ts] = self.classify(X_train_l=self.labeled[ts-1], L_train_l=self.labeled[ts], X_train_u=self.unlabeled[ts], X_test=self.labeled[ts+1], L_test=self.hypothesis[ts])
#     428                     t_end = time.time()
#     429                     elapsed_time = t_end - t_start
#
# ~/extreme_verification_latency/models/compose.py in classify(self, X_train_l, L_train_l, X_train_u, X_test, L_test)
#     290
#     291             model = ssl.QN_S3VM(X_train_l, L_train_l, X_train_u, random_gen)
# --> 292             model.train()
#     293             preds = model.getPredictions(X_test)
#     294             return preds
#
# ~/extreme_verification_latency/models/qns3vm.py in train(self)
#     142         The computed partition for the unlabeled patterns.
#     143         """
# --> 144         return self.__model.train()
#     145
#     146     def getPredictions(self, X, real_valued=False):
#
# ~/extreme_verification_latency/models/qns3vm.py in train(self)
#     239         The computed partition for the unlabeled patterns.
#     240         """
# --> 241         indi_opt = self.__optimize()
#     242         self.__recomputeModel(indi_opt)
#     243         predictions = self.__getTrainingPredictions(self.__X)
#
# ~/extreme_verification_latency/models/qns3vm.py in __optimize(self)
#     354         logging.debug("Starting optimization with BFGS ...")
#     355         self.__needed_function_calls = 0
# --> 356         self.__initializeMatrices()
#     357         # starting point
#     358         c_current = zeros(self.__dim, float64)
#
# ~/extreme_verification_latency/models/qns3vm.py in __initializeMatrices(self)
#     407             self.__KU_barU_bar_sum = (1.0 / (len(self.__X_u_subset)))**2 * self.__KU_barU_bar.sum()
#     408             self.__KNR = self.__KNR - self.__KNU_bar_horizontal_sum - self.__KU_barR_vertical_sum + self.__KU_barU_bar_sum
# --> 409             self.__KRR = self.__KNR[self.__regressors_indices,:]
#     410             self.__KLR = self.__KNR[range(0,len(self.__X_l)),:]
#     411             self.__KUR = self.__KNR[range(len(self.__X_l),len(self.__X)),:]
#
# /opt/anaconda3/lib/python3.7/site-packages/numpy/matrixlib/defmatrix.py in __getitem__(self, index)
#     193
#     194         try:
# --> 195             out = N.ndarray.__getitem__(self, index)
#     196         finally:
#     197             self._getitem = False
#
# /opt/anaconda3/lib/python3.7/site-packages/numpy/matrixlib/defmatrix.py in __array_finalize__(self, obj)
#     167         return ret
#     168
# --> 169     def __array_finalize__(self, obj):
#     170         self._getitem = False
#     171         if (isinstance(obj, matrix) and obj._getitem): return
#
# KeyboardInterrupt:
