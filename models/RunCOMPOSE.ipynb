# %% [markdown]
# Running Extreme Verification Latency Algorithms with the following classifiers:
# QN_S3VM
# Label Propagation
#
# The following parameters need to be passed in:
# 1. classifier : QN_S3VM or label_propagation
# 2. method : type of clustering 'gmm' or 'a_shape'
#     - gmm accounts for Fast COMPOSE
#     - a_shape accounts for alpha shapes
# 3. verbose : 0: doesnt print out , 1 prints to command line
# 4. num_cores: percent in which you wish to operate 0.8 = 80% of available cores
# 5. selected dataset : options available :
# ['UG_2C_2D','MG_2C_2D','1CDT', '2CDT', 'UG_2C_3D','1CHT','2CHT','4CR','4CREV1','4CREV2','5CVT','1CSURR', '4CE1CF','FG_2C_2D','GEARS_2C_2D', 'keystroke', 'UG_2C_5D', 'UnitTest']
#
# You are able to run in batch mode by running run_experiments.py
#
# You will need to instantiate RunExperiment Class and pass in the experiments, classifier, verbose, dataset, and number of cores.
#
# The number of cores is a percentage in which you want to operate: 1.0 means you will use all available cores, 0.8 means that you will use 80% of avaialable cores.

# %%
import run_experiments

experiment = run_experiments.RunExperiment(experiements=['fast_compose', 'compose'], classifier=['QN_S3VM', 'label_propagation'], 
                                            verbose=0, datasets=['UG_2C_2D','MG_2C_2D','1CDT', '2CDT'], num_cores=0.8)

run_it = experiment.run()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-882a3a8e4080> in <module>
#       4                                             verbose=0, datasets=['UG_2C_2D','MG_2C_2D','1CDT', '2CDT'], num_cores=0.8)
#       5
# ----> 6 run_it = experiment.run()
#
# ~/extreme_verification_latency/models/run_experiments.py in run(self)
#      68                     if i == 'fast_compose' and j == 'QN_S3VM':
#      69                         fast_compose_QNS3VM = compose.COMPOSE(classifier="QN_S3VM", method="gmm", verbose = self.verbose, num_cores= self.num_cores, selected_dataset = dataset)
# ---> 70                         self.results['fast_compose_QN_S3VM'] = fast_compose_QNS3VM.run()
#      71                         print(fast_compose_QNS3VM.avg_results)
#      72                     elif i == 'fast_compose' and j == 'label_propagation':
#
# ~/extreme_verification_latency/models/compose.py in run(self)
#     424                         self.labeled[ts-1] = np.append(self.labeled[ts-1], np.ones((rows_to_add,np.shape(self.labeled[ts-1])[1])), axis=0)
#     425
# --> 426                     self.learner[ts] = self.classify(X_train_l=self.labeled[ts-1], L_train_l=self.labeled[ts], X_train_u=self.unlabeled[ts], X_test=self.labeled[ts+1], L_test=self.hypothesis[ts])
#     427                     t_end = time.time()
#     428                     elapsed_time = t_end - t_start
#
# ~/extreme_verification_latency/models/compose.py in classify(self, X_train_l, L_train_l, X_train_u, X_test, L_test)
#     287
#     288             model = ssl.QN_S3VM(X_train_l, L_train_l, X_train_u, random_gen)
# --> 289             model.train()
#     290             preds = model.getPredictions(X_test)
#     291             return preds
#
# ~/extreme_verification_latency/models/qns3vm.py in train(self)
#     142         The computed partition for the unlabeled patterns.
#     143         """
# --> 144         return self.__model.train()
#     145
#     146     def getPredictions(self, X, real_valued=False):
#
# ~/extreme_verification_latency/models/qns3vm.py in train(self)
#     239         The computed partition for the unlabeled patterns.
#     240         """
# --> 241         indi_opt = self.__optimize()
#     242         self.__recomputeModel(indi_opt)
#     243         predictions = self.__getTrainingPredictions(self.__X)
#
# ~/extreme_verification_latency/models/qns3vm.py in __optimize(self)
#     363             # crop one dimension (in case the offset b is fixed)
#     364             c_current = c_current[:self.__dim-1]
# --> 365             c_current = self.__localSearch(c_current)
#     366             # reappend it if needed
#     367             c_current = np.append(c_current, self.__b)
#
# ~/extreme_verification_latency/models/qns3vm.py in __localSearch(self, start)
#     372         c_opt, f_opt, d = optimize.fmin_l_bfgs_b(self.__getFitness, start, m=self.__BFGS_m, \
#     373                             fprime=self.__getFitness_Prime, maxfun=self.__BFGS_maxfun, factr=self.__BFGS_factr,\
# --> 374                             pgtol=self.__BFGS_pgtol, iprint=self.__BFGS_verbose)
#     375         self.__needed_function_calls += int(d['funcalls'])
#     376         return c_opt
#
# /opt/anaconda3/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     197
#     198     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 199                            **opts)
#     200     d = {'grad': res['jac'],
#     201          'task': res['message'],
#
# /opt/anaconda3/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     333             # until the completion of the current minimization iteration.
#     334             # Overwrite f and g:
# --> 335             f, g = func_and_grad(x)
#     336         elif task_str.startswith(b'NEW_X'):
#     337             # new iteration
#
# /opt/anaconda3/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in func_and_grad(x)
#     284         def func_and_grad(x):
#     285             f = fun(x, *args)
# --> 286             g = jac(x, *args)
#     287             return f, g
#     288
#
# ~/extreme_verification_latency/models/qns3vm.py in __getFitness_Prime(self, c)
#     466         term1 = (-1.0/self.__size_l) * (term1.T * self.__KLR).T
#     467         term2 = ((-2.0 * self.__s * self.__lamU)/float(self.__size_u)) * (preds_unlabeled_squared_exp_f.T * self.__KUR).T
# --> 468         term3 = 2*self.__lam*(self.__KRR * c_new)
#     469         return array((term1 + term2 + term3).T)[0]
#     470
#
# /opt/anaconda3/lib/python3.7/site-packages/numpy/matrixlib/defmatrix.py in __mul__(self, other)
#     218         if isinstance(other, (N.ndarray, list, tuple)) :
#     219             # This promotes 1-D vectors to row vectors
# --> 220             return N.dot(self, asmatrix(other))
#     221         if isscalar(other) or not hasattr(other, '__rmul__') :
#     222             return N.dot(self, other)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:
